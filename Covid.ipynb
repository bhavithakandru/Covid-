# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
deaths = pd.read_csv('/Users/bhavithakandru/Desktop/work/archive/COVID DEATHS.csv')
vaccine = pd.read_csv('/Users/bhavithakandru/Desktop/work/archive/COVID_VACCINATIONS.csv')
vaccine
# Out:
#        iso_code continent     location       date  total_tests  new_tests  \
# 0           AFG      Asia  Afghanistan   1/3/2020          NaN        NaN
# 1           AFG      Asia  Afghanistan   1/4/2020          NaN        NaN
# 2           AFG      Asia  Afghanistan   1/5/2020          NaN        NaN
# 3           AFG      Asia  Afghanistan   1/6/2020          NaN        NaN
# 4           AFG      Asia  Afghanistan   1/7/2020          NaN        NaN
# ...         ...       ...          ...        ...          ...        ...
# 302744      ZWE    Africa     Zimbabwe   4/8/2023          NaN        NaN
# 302745      ZWE    Africa     Zimbabwe   4/9/2023          NaN        NaN
# 302746      ZWE    Africa     Zimbabwe  4/10/2023          NaN        NaN
# 302747      ZWE    Africa     Zimbabwe  4/11/2023          NaN        NaN
# 302748      ZWE    Africa     Zimbabwe  4/12/2023          NaN        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# ...

# %%
plot=sns.displot(deaths['continent'])
plt.xticks(rotation=90)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Asia'),
#   Text(1, 0, 'Europe'),
#   Text(2, 0, 'Africa'),
#   Text(3, 0, 'Oceania'),
#   Text(4, 0, 'North America'),
#   Text(5, 0, 'South America')])

# %%
combine = pd.concat([deaths,vaccine],axis=1,join='outer')
combine.head()
#sns.displot(combine['continent'])
#plt.x_ticks(rotation=90)
# Out:
#   iso_code continent     location      date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  1/3/2020    41128772          NaN
# 1      AFG      Asia  Afghanistan  1/4/2020    41128772          NaN
# 2      AFG      Asia  Afghanistan  1/5/2020    41128772          NaN
# 3      AFG      Asia  Afghanistan  1/6/2020    41128772          NaN
# 4      AFG      Asia  Afghanistan  1/7/2020    41128772          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        0.0                 NaN           NaN         0.0  ...
# 1        0.0                 NaN           NaN         0.0  ...
# 2        0.0                 NaN           NaN         0.0  ...
# 3        0.0                 NaN           NaN         0.0  ...
# 4        0.0                 NaN           NaN         0.0  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                   37.75
# ...

# %%
df1 = deaths[['population','total_deaths','total_cases']]
df2 = vaccine[['male_smokers','female_smokers']]
df = pd.concat([df1,df2],axis=0,join='outer')
sns.displot[df('population')]
plt.x_ticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 4
#       2 df2 = vaccine[['male_smokers','female_smokers']]
#       3 df = pd.concat([df1,df2],axis=0,join='outer')
# ----> 4 sns.displot[df('population')]
#       5 plt.x_ticks(rotation=90)
#
# TypeError: 'DataFrame' object is not callable
